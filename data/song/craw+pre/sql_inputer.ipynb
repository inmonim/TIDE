# %%
import pandas as pd
from urllib.parse import quote
from sqlalchemy import create_engine
import pymysql

from sqlalchemy import Table, MetaData
from sqlalchemy import insert, delete

# %%
user = 'root'
password = '3xlasql'
host = 'J8E203.p.ssafy.io'
port = '3306'
database = 'music'

# %%
engine = create_engine(f'mysql+pymysql://{user}:{quote(password)}@{host}:{port}/{database}', echo=True)

# meta = MetaData()
conn = engine.connect()
# Out:
# 2023-03-29 14:17:29,823 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2023-03-29 14:17:29,824 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-03-29 14:17:29,857 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2023-03-29 14:17:29,858 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-03-29 14:17:29,872 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2023-03-29 14:17:29,872 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
song_df = pd.read_csv('../song_data/song.csv', encoding='cp949', index_col=0)
song_genre_df = pd.read_csv('../song_data/song_genre.csv', encoding='cp949', index_col=0)
song_artist_df = pd.read_csv('../song_data/song_artist.csv', encoding='cp949', index_col=0)
song_album_df = pd.read_csv('../song_data/song_album.csv', encoding='cp949', index_col=0)
lyrics_df = pd.read_csv('../song_data/lyrics.csv', index_col=0)
group_artist_df = pd.read_csv('../song_data/group_artist.csv', encoding='cp949', index_col=0)
genre_df = pd.read_csv('../song_data/genre.csv', index_col=0)
artist_df = pd.read_csv('../song_data/artist.csv', index_col=0)
album_df = pd.read_csv('../song_data/album.csv', index_col=0)

# %%
emotion_df = pd.read_csv('../../emo/lyrics_emotion_ver3_3_notitle.csv', index_col=0)
emotion_df = emotion_df.rename(columns={'1emo':'emotion_1', '2emo':'emotion_2', '3emo':'emotion_3'})
keysen_df = pd.read_csv('../../emo/lyrics_keysen_notitle.csv', index_col=0)

keysen_df
# Out:
#        song_id           key_sentence
# 1        52441   짙은 어둠에서 서성거렸나 마음을 닫아
# 2        53060      묶인 살아서 만나리라 솔아 솔아
# 3      1017150  없이 찾아드는 기다림 사랑의 시작이었어
# 4        53018      젖은 바람은 이젠 희미해진 추억
# 5      1859404                사랑했던 추억
# ...        ...                    ...
# 9130  30117119        왔다 했죠 눈물진 나의 뺨을
# 9131   2795225           눈빛속의 잔인한 눈빛도
# 9132    469788     영원히 so you don cry
# 9133   8115185          liar oh 말도 어느
# 9134   4285745     dessert 제일 좋아하는 콜라
#
# [9134 rows x 2 columns]

# %%
for i in range(1, len(keysen_df)+1):
    emotion_df.loc[i, 'key_sentence'] = keysen_df.loc[i, 'key_sentence']

emotion_df.to_csv('song_emotion_keyword.csv')

# %%
def db_input(df, name):
    df.to_sql(index='id',
          name=name,
          con=engine,
          if_exists='append',
          method='multi',
          chunksize=10000,
          )

# %%
db_input(emotion_df, 'song_emotion_keyword')
# Out:
# 2023-03-29 14:20:38,537 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-29 14:20:38,538 INFO sqlalchemy.engine.Engine DESCRIBE `music`.`song_emotion_keyword`
# 2023-03-29 14:20:38,539 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-03-29 14:20:38,552 INFO sqlalchemy.engine.Engine ROLLBACK
# 2023-03-29 14:20:38,565 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-29 14:20:38,567 INFO sqlalchemy.engine.Engine
# CREATE TABLE song_emotion_keyword (
# 	id BIGINT,
# 	song_id BIGINT,
# 	emotion_1 BIGINT,
# 	emotion_2 BIGINT,
# 	emotion_3 BIGINT,
# 	key_sentence TEXT
# )
#
#
# 2023-03-29 14:20:38,568 INFO sqlalchemy.engine.Engine [no key 0.00082s] {}
# 2023-03-29 14:20:38,589 INFO sqlalchemy.engine.Engine CREATE INDEX ix_song_emotion_keyword_id ON song_emotion_keyword (id)
# 2023-03-29 14:20:38,590 INFO sqlalchemy.engine.Engine [no key 0.00100s] {}
# 2023-03-29 14:20:38,629 INFO sqlalchemy.engine.Engine COMMIT
# 2023-03-29 14:20:38,655 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-29 14:20:39,530 INFO sqlalchemy.engine.Engine INSERT INTO song_emotion_keyword (id, song_id, emotion_1, emotion_2, emotion_3, key_sentence) VALUES (%(id_m0)s, %(song_id_m0)s, %(emotion_1_m0)s, %(emotion_2_m0)s, %(emotion_3_m0)s, %(key_sentence_m0)s), (%(id_m1)s, %(song_id_m1)s, %(emotion_1_m1)s, %(emotion_2_m1)s, %(emotion_3_m1)s, %(key_sentence_m1)s), (%(id_m2)s, %(song_id_m2)s, %(emotion_1_m2)s, %(emotion_2_m2)s, %(emotion_3_m2)s, %(key_sentence_m2)s), (%(id_m3)s, %(song_id_m3)s, %(emotion_1_m3)s, %(emotion_2_m3)s, %(emotion_3_m3)s, %(key_sentence_m3)s), (%(id_m4)s, %(song_id_m4)s, %(emotion_1_m4)s, %(emotion_2_m4)s, %(emotion_3_m4)s, %(key_sentence_m4)s), (%(id_m5)s, %(song_id_m5)s, %(emotion_1_m5)s, %(emotion_2_m5)s, %(emotion_3_m5)s, %(key_sentence_m5)s), (%(id_m6)s, %(song_id_m6)s, %(emotion_1_m6)s, %(emotion_2_m6)s, %(emotion_3_m6)s, %(key_sentence_m6)s), (%(id_m7)s, %(song_id_m7)s, %(emotion_1_m7)s, %(emotion_2_m7)s, %(emotion_3_m7)s, %(key_sentence_m7)s), (%(id_m8)s, %(song_id_m8)s, %(emotion_1_m8)s, %(emotion_2_m8)s, %(emotion_3_m8)s, %(key_sentence_m8)s), (%(id_m9)s, %(song_id_m9)s, %(emotion_1_m9)s, %(emotion_2_m9)s, %(emotion_3_m9)s, %(key_sentence_m9)s), (%(id_m10)s, %(song_id_m10)s, %(emotion_1_m10)s, %(emotion_2_m10)s, %(emotion_3_m10)s, %(key_sentence_m10)s), (%(id_m11)s, %(song_id_m11)s, %(emotion_1_m11)s, %(emotion_2_m11)s, %(emotion_3_m11)s, %(key_sentence_m11)s), (%(id_m12)s, %(song_id_m12)s, %(emotion_1_m12)s, %(emotion_2_m12)s, %(emotion_3_m12)s, %(key_sentence_m12)s), (%(id_m13)s, %(song_id_m13)s, %(emotion_1_m13)s, %(emotion_2_m13)s, %(emotion_3_m13)s, %(key_sentence_m13)s), (%(id_m14)s, %(song_id_m14)s, %(emotion_1_m14)s, %(emotion_2_m14)s, %(emotion_3_m14)s, %(key_sentence_m14)s), (%(id_m15)s, %(song_id_m15)s, %(emotion_1_m15)s, %(emotion_2_m15)s, %(emotion_3_m15)s, %(key_sentence_m15)s), (%(id_m16)s, %(song_id_m16)s, %(emotion_1_m16)s, %(emotion_2_m16)s, %(emotion_3_m16)s, %(key_sentence_m16)s), (%(id_m17)s, %(song_id_m17)s, %(emotion_1_m17)s, %(emotion_2_m17)s, %(emotion_3_m17)s, %(key_sentence_m17)s), (%(id_m18)s, %(song_id_m18)s, %(emotion_1_m18)s, %(emotion_2_m18)s, %(emotion_3_m18)s, %(key_sentence_m18)s), (%(id_m19)s, %(song_id_m19)s, %(emotion_1_m19)s, %(emotion_2_m19)s, %(emotion_3_m19)s, %(key_sentence_m19)s), (%(id_m20)s, %(song_id_m20)s, %(emotion_1_m20)s, %(emotion_2_m20)s, %(emotion_3_m20)s, %(key_sentence_m20)s), (%(id_m21)s, %(song_id_m21)s, %(emotion_1_m21)s, %(emotion_2_m21)s, %(emotion_3_m21)s, %(key_sentence_m21)s), (%(id_m22)s, %(song_id_m22)s, %(emotion_1_m22)s, %(emotion_2_m22)s, %(emotion_3_m22)s, %(key_sentence_m22)s), (%(id_m23)s, %(song_id_m23)s, %(emotion_1_m23)s, %(emotion_2_m23)s, %(emotion_3_m23)s, %(key_sentence_m23)s), (%(id_m24)s, %(song_id_m24)s, %(emotion_1_m24)s, %(emotion_2_m24)s, %(emotion_3_m24)s, %(key_sentence_m24)s), (%(id_m25)s, %(song_id_m25)s, %(emotion_1_m25)s, %(emotion_2_m25)s, %(emotion_3_m25)s, %(key_sentence_m25)s), (%(id_m26)s, %(song_id_m26)s, %(emotion_1_m26)s, %(emotion_2_m26)s, %(emotion_3_m26)s, %(key_sentence_m26)s), (%(id_m27)s, %(song_id_m27)s, %(emotion_1_m27)s, %(emotion_2_m27)s, %(emotion_3_m27)s, %(key_sentence_m27)s), (%(id_m28)s, %(song_id_m28)s, %(emotion_1_m28)s, %(emotion_2_m28)s, %(emotion_3_m28)s, %(key_sentence_m28)s), (%(id_m29)s, %(song_id_m29)s, %(emotion_1_m29)s, %(emotion_2_m29)s, %(emotion_3_m29)s, %(key_sentence_m29)s), (%(id_m30)s, %(song_id_m30)s, %(emotion_1_m30)s, %(emotion_2_m30)s, %(emotion_3_m30)s, %(key_sentence_m30)s), (%(id_m31)s, %(song_id_m31)s, %(emotion_1_m31)s, %(emotion_2_m31)s, %(emotion_3_m31)s, %(key_sentence_m31)s), (%(id_m32)s, %(song_id_m32)s, %(emotion_1_m32)s, %(emotion_2_m32)s, %(emotion_3_m32)s, %(key_sentence_m32)s), (%(id_m33)s, %(song_id_m33)s, %(emotion_1_m33)s, %(emotion_2_m33)s, %(emotion_3_m33)s, %(key_sentence_m33)s), (%(id_m34)s, %(song_id_m34)s, %(emotion_1_m34)s, %(emotion_2_m34)s, %(emotion_3_m34)s, %(key_sentence_m34)s), (%(id_m35)s, %(song_id_m35)s, %(emotion_1_m35)s, %(emot ...
# 2023-03-29 14:20:39,538 INFO sqlalchemy.engine.Engine [no key 0.06436s] {'id_m0': 1, 'song_id_m0': 52441, 'emotion_1_m0': 8, 'emotion_2_m0': 13, 'emotion_3_m0': 14, 'key_sentence_m0': '짙은 어둠에서 서성거렸나 마음을 닫아', 'id_m1': 2, 'song_id_m1': 53060, 'emotion_1_m1': 3, 'emotion_2_m1': 4, 'emotion_3_m1': 11, 'key_sentence_m1': '묶인 살아서 만나리라 솔아 솔아', 'id_m2': 3, 'song_id_m2': 1017150, 'emotion_1_m2': 3, 'emotion_2_m2': 18, 'emotion_3_m2': 12, 'key_sentence_m2': '없이 찾아드는 기다림 사랑의 시작이었어', 'id_m3': 4, 'song_id_m3': 53018, 'emotion_1_m3': 3, 'emotion_2_m3': 18, 'emotion_3_m3': 12, 'key_sentence_m3': '젖은 바람은 이젠 희미해진 추억', 'id_m4': 5, 'song_id_m4': 1859404, 'emotion_1_m4': 3, 'emotion_2_m4': 1, 'emotion_3_m4': 18, 'key_sentence_m4': '사랑했던 추억', 'id_m5': 6, 'song_id_m5': 52841, 'emotion_1_m5': 2, 'emotion_2_m5': 1, 'emotion_3_m5': 18, 'key_sentence_m5': '떠나간 사람 정주고 마음주고 사랑도', 'id_m6': 7, 'song_id_m6': 51275, 'emotion_1_m6': 5, 'emotion_2_m6': 1, 'emotion_3_m6': 16, 'key_sentence_m6': '내가 처음 만난', 'id_m7': 8, 'song_id_m7': 1104907, 'emotion_1_m7': 8, 'emotion_2_m7': 6, 'emotion_3_m7': 11, 'key_sentence_m7': '꿈이란 이런 거라 하지만 나는', 'id_m8': 9, 'song_id_m8': 1839744 ... 54704 parameters truncated ... 'emotion_3_m9125': 13, 'key_sentence_m9125': '들리는 음악은 지루한 하루 건너', 'id_m9126': 9127, 'song_id_m9126': 3675624, 'emotion_1_m9126': 5, 'emotion_2_m9126': 11, 'emotion_3_m9126': 16, 'key_sentence_m9126': '풍문으로 들었소 마음은 서러워 나는', 'id_m9127': 9128, 'song_id_m9127': 31083695, 'emotion_1_m9127': 1, 'emotion_2_m9127': 15, 'emotion_3_m9127': 12, 'key_sentence_m9127': '바랬죠 우리의 마지막 날이 저물어', 'id_m9128': 9129, 'song_id_m9128': 2650367, 'emotion_1_m9128': 3, 'emotion_2_m9128': 20, 'emotion_3_m9128': 18, 'key_sentence_m9128': '넘어지면 어때 살다보면 살아가다 보면', 'id_m9129': 9130, 'song_id_m9129': 30117119, 'emotion_1_m9129': 3, 'emotion_2_m9129': 8, 'emotion_3_m9129': 7, 'key_sentence_m9129': '왔다 했죠 눈물진 나의 뺨을', 'id_m9130': 9131, 'song_id_m9130': 2795225, 'emotion_1_m9130': 8, 'emotion_2_m9130': 3, 'emotion_3_m9130': 7, 'key_sentence_m9130': '눈빛속의 잔인한 눈빛도', 'id_m9131': 9132, 'song_id_m9131': 469788, 'emotion_1_m9131': 8, 'emotion_2_m9131': 3, 'emotion_3_m9131': 11, 'key_sentence_m9131': '영원히 so you don cry', 'id_m9132': 9133, 'song_id_m9132': 8115185, 'emotion_1_m9132': 11, 'emotion_2_m9132': 18, 'emotion_3_m9132': 12, 'key_sentence_m9132': 'liar oh 말도 어느', 'id_m9133': 9134, 'song_id_m9133': 4285745, 'emotion_1_m9133': 10, 'emotion_2_m9133': 6, 'emotion_3_m9133': 9, 'key_sentence_m9133': 'dessert 제일 좋아하는 콜라'}
# 2023-03-29 14:20:39,912 INFO sqlalchemy.engine.Engine COMMIT
